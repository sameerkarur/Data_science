# %% [markdown]
# # Classification Algorithms
#
# Open in Jupyter, run each cell, write your code below each question.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd
# Dataset path (from repo root)
# df = pd.read_csv('datasets/shared/AusApparalSales4thQrt2020.csv')
print('Ready — Classification Algorithms')

# %% [markdown]
# ## Warm-up
# Review basics.md then solve.

# %%
# Your code here

# %% [markdown]
# ## Core exercises
# Apply concepts from the lesson.

# %%
# Your code here

# %% [markdown]
# ## Interview challenge
# Solve without looking at notes.

# %%
# Your code here
