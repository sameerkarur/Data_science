# %% [markdown]
# <a href="https://colab.research.google.com/github/sameerkarur/Data_science/blob/main/03_IITK_AIML_Core_Machine_Learning/05_model_evaluation/solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Model Evaluation — Solutions
#
# Run setup first, then each solution cell.

# %% [markdown]
# ## Setup

# %%
from pathlib import Path
import os, sys, subprocess, urllib.request

# ⚡ Universal Colab & Workspace Setup
def setup_environment():
    if 'google.colab' in sys.modules or os.path.exists('/content'):
        colab_repo = Path('/content/Data_science')
        if not (colab_repo / 'datasets' / 'shared').exists():
            print("🚀 Google Colab detected: Cloning repository from GitHub to load shared datasets...")
            subprocess.run(['git', 'clone', '--depth', '1', 'https://github.com/sameerkarur/Data_science.git', str(colab_repo)], check=False)
        if colab_repo.exists():
            os.chdir(str(colab_repo))
            return colab_repo

    p = Path('.').resolve()
    for candidate in [p, *p.parents]:
        if (candidate / 'datasets' / 'shared').exists():
            return candidate
    return Path('.')

REPO_ROOT = setup_environment()
DATA_DIR = REPO_ROOT / 'datasets' / 'shared'

def ensure_dataset(filename):
    local_path = DATA_DIR / filename
    if not local_path.exists():
        DATA_DIR.mkdir(parents=True, exist_ok=True)
        raw_url = f"https://raw.githubusercontent.com/sameerkarur/Data_science/main/datasets/shared/{filename}"
        print(f"📥 Downloading {filename} from GitHub...")
        try:
            urllib.request.urlretrieve(raw_url, str(local_path))
        except Exception as e:
            print(f"Download failed: {e}")
    return local_path

print(f"Repo root : {REPO_ROOT}")
print(f"Datasets  : {DATA_DIR}")
if DATA_DIR.exists():
    print("Available CSVs:", sorted(p.name for p in DATA_DIR.glob('*.csv')))

import pandas as pd
import numpy as np

# Pure Python topic — no dataset required for most exercises
pass

# %% [markdown]
# ## Section 1: Concepts

# %% [markdown]
# **Q1.** Define Model Evaluation and give AIML example.

# %%
print('Model Evaluation — see basics.md')

# %% [markdown]
# **Q2.** Load loan_data.csv and describe `Sales`.

# %%
df = pd.read_csv(DATA_DIR / 'loan_data.csv')
print(df['Sales'].describe())

# %% [markdown]
# **Q3.** Compute mean, median, std of `Sales`.

# %%
df = pd.read_csv(DATA_DIR / 'loan_data.csv')
print(df['Sales'].mean(), df['Sales'].median(), df['Sales'].std())

# %% [markdown]
# **Q4.** Explain when to use Model Evaluation test vs alternative.

# %%
print('Depends on assumptions: normality, independence, sample size')

# %% [markdown]
# **Q5.** Simulate 1000 draws from normal; plot histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.random.normal(0, 1, 1000)
plt.hist(x, bins=30); plt.title('Model Evaluation'); plt.show()

# %% [markdown]
# **Q6.** Calculate 95% CI for mean of `Sales`.

# %%
df = pd.read_csv(DATA_DIR / 'loan_data.csv')
import numpy as np
x = df['Sales'].dropna()
se = x.std()/np.sqrt(len(x))
print(x.mean()-1.96*se, x.mean()+1.96*se)

# %% [markdown]
# **Q7.** State null and alternative hypothesis for Model Evaluation.

# %%
print('H0: no effect; H1: effect exists')

# %% [markdown]
# **Q8.** What alpha=0.05 means in Model Evaluation.

# %%
print('5% false positive rate if H0 true')

# %% [markdown]
# **Q9.** Type I vs Type II error in Model Evaluation.

# %%
print('Type I: reject true H0; Type II: fail reject false H0')

# %% [markdown]
# **Q10.** Check skewness of `Sales`.

# %%
df = pd.read_csv(DATA_DIR / 'loan_data.csv')
print(df['Sales'].skew())

# %% [markdown]
# ## Section 2: Computation

# %% [markdown]
# **Q11.** Define Model Evaluation and give AIML example.

# %%
print('Model Evaluation — see basics.md')

# %% [markdown]
# **Q12.** Load loan_data.csv and describe `Sales`.

# %%
df = pd.read_csv(DATA_DIR / 'loan_data.csv')
print(df['Sales'].describe())

# %% [markdown]
# **Q13.** Compute mean, median, std of `Sales`.

# %%
df = pd.read_csv(DATA_DIR / 'loan_data.csv')
print(df['Sales'].mean(), df['Sales'].median(), df['Sales'].std())

# %% [markdown]
# **Q14.** Explain when to use Model Evaluation test vs alternative.

# %%
print('Depends on assumptions: normality, independence, sample size')

# %% [markdown]
# **Q15.** Simulate 1000 draws from normal; plot histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.random.normal(0, 1, 1000)
plt.hist(x, bins=30); plt.title('Model Evaluation'); plt.show()

# %% [markdown]
# **Q16.** Calculate 95% CI for mean of `Sales`.

# %%
df = pd.read_csv(DATA_DIR / 'loan_data.csv')
import numpy as np
x = df['Sales'].dropna()
se = x.std()/np.sqrt(len(x))
print(x.mean()-1.96*se, x.mean()+1.96*se)

# %% [markdown]
# **Q17.** State null and alternative hypothesis for Model Evaluation.

# %%
print('H0: no effect; H1: effect exists')

# %% [markdown]
# **Q18.** What alpha=0.05 means in Model Evaluation.

# %%
print('5% false positive rate if H0 true')

# %% [markdown]
# **Q19.** Type I vs Type II error in Model Evaluation.

# %%
print('Type I: reject true H0; Type II: fail reject false H0')

# %% [markdown]
# **Q20.** Check skewness of `Sales`.

# %%
df = pd.read_csv(DATA_DIR / 'loan_data.csv')
print(df['Sales'].skew())

# %% [markdown]
# ## Section 3: Interpretation

# %% [markdown]
# **Q21.** Define Model Evaluation and give AIML example.

# %%
print('Model Evaluation — see basics.md')

# %% [markdown]
# **Q22.** Load loan_data.csv and describe `Sales`.

# %%
df = pd.read_csv(DATA_DIR / 'loan_data.csv')
print(df['Sales'].describe())

# %% [markdown]
# **Q23.** Compute mean, median, std of `Sales`.

# %%
df = pd.read_csv(DATA_DIR / 'loan_data.csv')
print(df['Sales'].mean(), df['Sales'].median(), df['Sales'].std())

# %% [markdown]
# **Q24.** Explain when to use Model Evaluation test vs alternative.

# %%
print('Depends on assumptions: normality, independence, sample size')

# %% [markdown]
# **Q25.** Simulate 1000 draws from normal; plot histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.random.normal(0, 1, 1000)
plt.hist(x, bins=30); plt.title('Model Evaluation'); plt.show()

# %% [markdown]
# **Q26.** Calculate 95% CI for mean of `Sales`.

# %%
df = pd.read_csv(DATA_DIR / 'loan_data.csv')
import numpy as np
x = df['Sales'].dropna()
se = x.std()/np.sqrt(len(x))
print(x.mean()-1.96*se, x.mean()+1.96*se)

# %% [markdown]
# **Q27.** State null and alternative hypothesis for Model Evaluation.

# %%
print('H0: no effect; H1: effect exists')

# %% [markdown]
# **Q28.** What alpha=0.05 means in Model Evaluation.

# %%
print('5% false positive rate if H0 true')

# %% [markdown]
# **Q29.** Type I vs Type II error in Model Evaluation.

# %%
print('Type I: reject true H0; Type II: fail reject false H0')

# %% [markdown]
# **Q30.** Check skewness of `Sales`.

# %%
df = pd.read_csv(DATA_DIR / 'loan_data.csv')
print(df['Sales'].skew())

# %% [markdown]
# ## Section 4: Applied

# %% [markdown]
# **Q31.** Define Model Evaluation and give AIML example.

# %%
print('Model Evaluation — see basics.md')

# %% [markdown]
# **Q32.** Load loan_data.csv and describe `Sales`.

# %%
df = pd.read_csv(DATA_DIR / 'loan_data.csv')
print(df['Sales'].describe())

# %% [markdown]
# **Q33.** Compute mean, median, std of `Sales`.

# %%
df = pd.read_csv(DATA_DIR / 'loan_data.csv')
print(df['Sales'].mean(), df['Sales'].median(), df['Sales'].std())

# %% [markdown]
# **Q34.** Explain when to use Model Evaluation test vs alternative.

# %%
print('Depends on assumptions: normality, independence, sample size')

# %% [markdown]
# **Q35.** Simulate 1000 draws from normal; plot histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.random.normal(0, 1, 1000)
plt.hist(x, bins=30); plt.title('Model Evaluation'); plt.show()

# %% [markdown]
# **Q36.** Calculate 95% CI for mean of `Sales`.

# %%
df = pd.read_csv(DATA_DIR / 'loan_data.csv')
import numpy as np
x = df['Sales'].dropna()
se = x.std()/np.sqrt(len(x))
print(x.mean()-1.96*se, x.mean()+1.96*se)

# %% [markdown]
# **Q37.** State null and alternative hypothesis for Model Evaluation.

# %%
print('H0: no effect; H1: effect exists')

# %% [markdown]
# **Q38.** What alpha=0.05 means in Model Evaluation.

# %%
print('5% false positive rate if H0 true')

# %% [markdown]
# **Q39.** Type I vs Type II error in Model Evaluation.

# %%
print('Type I: reject true H0; Type II: fail reject false H0')

# %% [markdown]
# **Q40.** Check skewness of `Sales`.

# %%
df = pd.read_csv(DATA_DIR / 'loan_data.csv')
print(df['Sales'].skew())

# %% [markdown]
# ## Section 5: Challenge

# %% [markdown]
# **Q41.** Define Model Evaluation and give AIML example.

# %%
print('Model Evaluation — see basics.md')

# %% [markdown]
# **Q42.** Load loan_data.csv and describe `Sales`.

# %%
df = pd.read_csv(DATA_DIR / 'loan_data.csv')
print(df['Sales'].describe())

# %% [markdown]
# **Q43.** Compute mean, median, std of `Sales`.

# %%
df = pd.read_csv(DATA_DIR / 'loan_data.csv')
print(df['Sales'].mean(), df['Sales'].median(), df['Sales'].std())

# %% [markdown]
# **Q44.** Explain when to use Model Evaluation test vs alternative.

# %%
print('Depends on assumptions: normality, independence, sample size')

# %% [markdown]
# **Q45.** Simulate 1000 draws from normal; plot histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.random.normal(0, 1, 1000)
plt.hist(x, bins=30); plt.title('Model Evaluation'); plt.show()

# %% [markdown]
# **Q46.** Calculate 95% CI for mean of `Sales`.

# %%
df = pd.read_csv(DATA_DIR / 'loan_data.csv')
import numpy as np
x = df['Sales'].dropna()
se = x.std()/np.sqrt(len(x))
print(x.mean()-1.96*se, x.mean()+1.96*se)

# %% [markdown]
# **Q47.** State null and alternative hypothesis for Model Evaluation.

# %%
print('H0: no effect; H1: effect exists')

# %% [markdown]
# **Q48.** What alpha=0.05 means in Model Evaluation.

# %%
print('5% false positive rate if H0 true')

# %% [markdown]
# **Q49.** Type I vs Type II error in Model Evaluation.

# %%
print('Type I: reject true H0; Type II: fail reject false H0')

# %% [markdown]
# **Q50.** Check skewness of `Sales`.

# %%
df = pd.read_csv(DATA_DIR / 'loan_data.csv')
print(df['Sales'].skew())
