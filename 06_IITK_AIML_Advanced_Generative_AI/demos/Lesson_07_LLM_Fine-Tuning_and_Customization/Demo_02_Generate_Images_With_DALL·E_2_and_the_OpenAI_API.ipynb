# %% [markdown]
# # **Demo 2-Generate Images With DALL·E 2 and the OpenAI API**

# %% [markdown]
# # **Description**
# In this project, you will learn how to use LangChain, an open-source framework that allows you to build applications with large language models (LLMs) such as OpenAI’s DALL-E.

# %% [markdown]
# # **Steps to perform:**
#
# 1. Setup the environment
# 2. Generate image from the text
# 3. Display the generated images

# %% [markdown]
# # **Step 1: Setup the environment**

# %%
import os
import openai

# %% [markdown]
# # **Step 2:  Generate image from the text**

# %%
Text_PROMPT = input("Enter a Text : ")



Image_response = openai.Image.create(
    prompt=Text_PROMPT,
    n=1,
    size="256x256",
)

print(Image_response["data"][0]["url"])
# Out:
# Enter a Text :  robot
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-9ZJZXfGRl4htozT4HbcRvg52/user-MzxoVaghXWtmz964fLli6RXW/img-V8zgsCBNE8dflNUxmNtSWOBJ.png?st=2024-07-08T08%3A48%3A34Z&se=2024-07-08T10%3A48%3A34Z&sp=r&sv=2023-11-03&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-07-08T02%3A28%3A45Z&ske=2024-07-09T02%3A28%3A45Z&sks=b&skv=2023-11-03&sig=31yxDHMlEyaEslXWp2MQif7Um7sIdJepl43VWyihl%2Bc%3D

# %% [markdown]
# **Observation:**
# - Click on the above link to locate the image you requested

# %% [markdown]
# # **Conclusion**
# By the end of this project, you will have gained experience in how to use LangChain and OpenAI to generate images from text.
