# %% [markdown]
# <a href="https://colab.research.google.com/github/sameerkarur/Data_science/blob/main/03_IITK_AIML_Core_Machine_Learning/02_clustering/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Clustering — Practice
#
# ## How to practice (read this first)
#
# 1. **Start Jupyter from repo root** so dataset paths resolve:
#    ```bash
#    cd Data_science
#    jupyter notebook
#    ```
# 2. Open this notebook (`practice.ipynb`) in the subtopic folder.
# 3. Run the **Setup** cell — it finds `datasets/shared/` automatically.
# 4. Read `basics.md` for syntax, then solve **one question at a time** in the code cell below it.
# 5. Do **not** peek at `solutions.ipynb` until you have a working attempt (even if wrong).
# 6. After all questions, review `interview_qa.md` aloud as mock interview answers.
# 7. **Pro tip:** Re-solve Q41–Q50 from memory the next day without notes.
#
# **Target:** 50 questions × 5 courses ≈ **1,250+ problems** in this repo (+ NumPy/Pandas/Matplotlib/Seaborn banks).

# %% [markdown]
# ## Setup & dataset loading

# %%
from pathlib import Path
import os, sys, subprocess, urllib.request

# ⚡ Universal Colab & Workspace Setup
def setup_environment():
    if 'google.colab' in sys.modules or os.path.exists('/content'):
        colab_repo = Path('/content/Data_science')
        if not (colab_repo / 'datasets' / 'shared').exists():
            print("🚀 Google Colab detected: Cloning repository from GitHub to load shared datasets...")
            subprocess.run(['git', 'clone', '--depth', '1', 'https://github.com/sameerkarur/Data_science.git', str(colab_repo)], check=False)
        if colab_repo.exists():
            os.chdir(str(colab_repo))
            return colab_repo

    p = Path('.').resolve()
    for candidate in [p, *p.parents]:
        if (candidate / 'datasets' / 'shared').exists():
            return candidate
    return Path('.')

REPO_ROOT = setup_environment()
DATA_DIR = REPO_ROOT / 'datasets' / 'shared'

def ensure_dataset(filename):
    local_path = DATA_DIR / filename
    if not local_path.exists():
        DATA_DIR.mkdir(parents=True, exist_ok=True)
        raw_url = f"https://raw.githubusercontent.com/sameerkarur/Data_science/main/datasets/shared/{filename}"
        print(f"📥 Downloading {filename} from GitHub...")
        try:
            urllib.request.urlretrieve(raw_url, str(local_path))
        except Exception as e:
            print(f"Download failed: {e}")
    return local_path

print(f"Repo root : {REPO_ROOT}")
print(f"Datasets  : {DATA_DIR}")
if DATA_DIR.exists():
    print("Available CSVs:", sorted(p.name for p in DATA_DIR.glob('*.csv')))

import pandas as pd
import numpy as np

# Pure Python topic — no dataset required for most exercises
pass

# %% [markdown]
# ## Section 1: Concepts

# %% [markdown]
# **Q1.** Define Clustering and give AIML example.

# %%
# Your code here

# %% [markdown]
# **Q2.** Load rolling_stones_spotify.csv and describe `Sales`.

# %%
# Your code here

# %% [markdown]
# **Q3.** Compute mean, median, std of `Sales`.

# %%
# Your code here

# %% [markdown]
# **Q4.** Explain when to use Clustering test vs alternative.

# %%
# Your code here

# %% [markdown]
# **Q5.** Simulate 1000 draws from normal; plot histogram.

# %%
# Your code here

# %% [markdown]
# **Q6.** Calculate 95% CI for mean of `Sales`.

# %%
# Your code here

# %% [markdown]
# **Q7.** State null and alternative hypothesis for Clustering.

# %%
# Your code here

# %% [markdown]
# **Q8.** What alpha=0.05 means in Clustering.

# %%
# Your code here

# %% [markdown]
# **Q9.** Type I vs Type II error in Clustering.

# %%
# Your code here

# %% [markdown]
# **Q10.** Check skewness of `Sales`.

# %%
# Your code here

# %% [markdown]
# ## Section 2: Computation

# %% [markdown]
# **Q11.** Define Clustering and give AIML example.

# %%
# Your code here

# %% [markdown]
# **Q12.** Load rolling_stones_spotify.csv and describe `Sales`.

# %%
# Your code here

# %% [markdown]
# **Q13.** Compute mean, median, std of `Sales`.

# %%
# Your code here

# %% [markdown]
# **Q14.** Explain when to use Clustering test vs alternative.

# %%
# Your code here

# %% [markdown]
# **Q15.** Simulate 1000 draws from normal; plot histogram.

# %%
# Your code here

# %% [markdown]
# **Q16.** Calculate 95% CI for mean of `Sales`.

# %%
# Your code here

# %% [markdown]
# **Q17.** State null and alternative hypothesis for Clustering.

# %%
# Your code here

# %% [markdown]
# **Q18.** What alpha=0.05 means in Clustering.

# %%
# Your code here

# %% [markdown]
# **Q19.** Type I vs Type II error in Clustering.

# %%
# Your code here

# %% [markdown]
# **Q20.** Check skewness of `Sales`.

# %%
# Your code here

# %% [markdown]
# ## Section 3: Interpretation

# %% [markdown]
# **Q21.** Define Clustering and give AIML example.

# %%
# Your code here

# %% [markdown]
# **Q22.** Load rolling_stones_spotify.csv and describe `Sales`.

# %%
# Your code here

# %% [markdown]
# **Q23.** Compute mean, median, std of `Sales`.

# %%
# Your code here

# %% [markdown]
# **Q24.** Explain when to use Clustering test vs alternative.

# %%
# Your code here

# %% [markdown]
# **Q25.** Simulate 1000 draws from normal; plot histogram.

# %%
# Your code here

# %% [markdown]
# **Q26.** Calculate 95% CI for mean of `Sales`.

# %%
# Your code here

# %% [markdown]
# **Q27.** State null and alternative hypothesis for Clustering.

# %%
# Your code here

# %% [markdown]
# **Q28.** What alpha=0.05 means in Clustering.

# %%
# Your code here

# %% [markdown]
# **Q29.** Type I vs Type II error in Clustering.

# %%
# Your code here

# %% [markdown]
# **Q30.** Check skewness of `Sales`.

# %%
# Your code here

# %% [markdown]
# ## Section 4: Applied

# %% [markdown]
# **Q31.** Define Clustering and give AIML example.

# %%
# Your code here

# %% [markdown]
# **Q32.** Load rolling_stones_spotify.csv and describe `Sales`.

# %%
# Your code here

# %% [markdown]
# **Q33.** Compute mean, median, std of `Sales`.

# %%
# Your code here

# %% [markdown]
# **Q34.** Explain when to use Clustering test vs alternative.

# %%
# Your code here

# %% [markdown]
# **Q35.** Simulate 1000 draws from normal; plot histogram.

# %%
# Your code here

# %% [markdown]
# **Q36.** Calculate 95% CI for mean of `Sales`.

# %%
# Your code here

# %% [markdown]
# **Q37.** State null and alternative hypothesis for Clustering.

# %%
# Your code here

# %% [markdown]
# **Q38.** What alpha=0.05 means in Clustering.

# %%
# Your code here

# %% [markdown]
# **Q39.** Type I vs Type II error in Clustering.

# %%
# Your code here

# %% [markdown]
# **Q40.** Check skewness of `Sales`.

# %%
# Your code here

# %% [markdown]
# ## Section 5: Challenge

# %% [markdown]
# **Q41.** Define Clustering and give AIML example.

# %%
# Your code here

# %% [markdown]
# **Q42.** Load rolling_stones_spotify.csv and describe `Sales`.

# %%
# Your code here

# %% [markdown]
# **Q43.** Compute mean, median, std of `Sales`.

# %%
# Your code here

# %% [markdown]
# **Q44.** Explain when to use Clustering test vs alternative.

# %%
# Your code here

# %% [markdown]
# **Q45.** Simulate 1000 draws from normal; plot histogram.

# %%
# Your code here

# %% [markdown]
# **Q46.** Calculate 95% CI for mean of `Sales`.

# %%
# Your code here

# %% [markdown]
# **Q47.** State null and alternative hypothesis for Clustering.

# %%
# Your code here

# %% [markdown]
# **Q48.** What alpha=0.05 means in Clustering.

# %%
# Your code here

# %% [markdown]
# **Q49.** Type I vs Type II error in Clustering.

# %%
# Your code here

# %% [markdown]
# **Q50.** Check skewness of `Sales`.

# %%
# Your code here
