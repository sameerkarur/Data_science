# %% [markdown]
# # **Demo: Text Summarizer**
#
# In this demo, you will create an Arxiv paper summarizer that downloads a paper as a PDF, reads it in one shot, and generates a summary. You can use the **The Impact of Generative Artificial Intelligence** paper as an example for demonstration.

# %% [markdown]
# ## **Steps to Perform:**
#
# *   Step 1: Import the Necessary Libraries
# *   Step 2: Download and Read the PDF
# *   Step 3: Extract Text from the PDF
# *   Step 4: Count the Tokens in the Extracted Text
# *   Step 5: Use LangChain to Generate a Summary of the Paper

# %% [markdown]
# ### **Step 1: Import the Necessary Libraries**

# %%
import os
import requests
from PyPDF2 import PdfReader
import tiktoken
from langchain.prompts import (
    ChatPromptTemplate,
    PromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
)
from langchain.schema import (
    AIMessage,
    HumanMessage,
    SystemMessage
)
from langchain.chat_models import ChatOpenAI
from langchain.chains import LLMChain
from langchain.callbacks import get_openai_callback

# %% [markdown]
# ### **Step 2: Download and Read the PDF**
#
# *   Define the path of the paper.
# *   Read the PDF using **PdfReader**.
# *   Print the number of pages.

# %%
# Define the path of the paper
PAPER_PATH = "arxiv_impact_of_GENAI.pdf"

# Read the PDF
reader = PdfReader(PAPER_PATH)

# Print the number of pages in the PDF
print(f"Number of pages: {len(reader.pages)}")
# Out:
# Number of pages: 9

# %% [markdown]
# ### **Step 3: Extract Text from the PDF**
#
# *   Initialize an empty list to store text parts.
# *   Define a function to visit the body of the text.
# *   Extract the text from each page of the PDF.
# *   Join the parts of the text into a single string.
# *   Print the extracted text.

# %%
# Initialize an empty list to store the parts of the text
parts = []

# Define a function to visit the body of the text
def visitor_body(text, cm, tm, fontDict, fontSize):
    y = tm[5]
    if y > 50 and y < 720:
        parts.append(text)

# Extract the text from each page of the PDF
for page in reader.pages:
    page.extract_text(visitor_text=visitor_body)

# Join the parts of the text into a single string
text_body = "".join(parts)

# Print the extracted text
print(text_body)
# Out:
# The Impact of Generative Artificial Intelligence
# Kaichen Zhang1,2, Ohchan Kwon2, Hui Xiong1,2
# 1Hong Kong University of Science and Technology (Guangzhou)
# 2Hong Kong University of Science and Technology
# kzhangbi@connect.ust.hk, ohchankw@ust.hk, xionghui@ust.hk
# Abstract
# The rise of generative artificial intelligence (AI) has sparked
# concerns about its potential influence on unemployment and
# market depression. This study addresses this concern by ex-
# amining the impact of generative AI on product markets. To
# overcome the challenge of causal inference, given the inher-
# ent limitations of conducting controlled experiments, this pa-
# per identifies an unanticipated and sudden leak of a highly
# proficient image-generative AI as a novel instance of a ”natu-
# ral experiment.” This AI leak spread rapidly, significantly re-
# ducing the cost of generating anime-style images compared to
# other styles, creating an opportunity for comparative assess-
# ment. We collect real-world data from an artwork outsourcing
# platform. Surprisingly, our results show that while generative
# AI lowers average prices, it substantially boosts order volume
# and overall revenue. This counterintuitive finding suggests
# that generative AI confers benefits upon artists rather than
# detriments. The study further offers theoretical economic ex-
# planations to elucidate this unexpected phenomenon. By fur-
# nishing empirical evidence, this paper dispels the notion that
# generative AI might engender depression, instead underscor-
# ing its potential to foster market prosperity. These findings
# carry significant implications for practitioners, policymakers,
# and the broader AI community.
# Introduction
# Generative artificial intelligence (AI) seems to propel our
# world closer to the realm of Cyberpunk—a futuristic milieu
# characterized by the coexistence of ”high tech and low life.”
# This juxtaposition portrays a world where remarkable tech-
# nological and scientific strides coalesce with societal break-
# down, dystopia, and deterioration. The potential of genera-
# tive AI is profound; it can swiftly produce intricate paintings
# or eloquent articles in direct response to human requisites.
# However, the rapid development of generative AI also begets
# apprehensions regarding workforce displacement and mar-
# ket depression, thereby amplifying prevailing social dispari-
# ties and fortifying the dominance of corporate behemoths.
# In response to generative AI, artists have staged mass
# protests with the slogan ”NO to Ai generated images,” a
# sentiment depicted in Figure 1. Additionally, the EU is also
# contemplating new regulations to limit generative AI use.
# In response, Elon Musk has appealed to the AI community
# to pause the development of such technology. However, he
# has encountered staunch opposition from others who believe
# Figure 1: Artists Yelling at Generative AI.
# that generative AI will not be detrimental to society. Notably,
# (Friedman 1953) hints that differences in views on gen-
# erative AI may stem from different economic predictions,
# which can be resolved with compelling evidence. Thus, this
# paper empirically examines the impact of generative AI on
# product markets to bridge these gaps.
# The primary hurdle in assessing the impact of generative
# AI lies in achieving causal inference . This involves estab-
# lishing a genuine cause-and-effect relationship between gen-
# erative AI and the key outcome variables, rather than mere
# correlation. A straightforward yet unsophisticated approach
# is to contrast the outcome variable (e.g., the number of or-
# ders) before and after the emergence of generative AI. How-
# ever, this method lacks the capacity for causal inference.
# For instance, observing a rise in crime rates alongside in-
# creased ice cream sales doesn’t imply that ice cream causes
# criminal behavior; the true factor may be the seasonal influ-
# ence of summer. Another avenue is randomized experiments
# (or A/B testings), which offer the most compelling evidence
# for causality. Yet, applying experiments to study generative
# AI’s impact on product markets is unfeasible. The challenge
# emerges from the inability to identify equivalent markets, in-
# troduce and promote new generative AI in selected markets,
# primarily due to the exorbitant costs involved. For instance,
# training a GPT-3 model incurs costs exceeding $4.6 million.
# These financial, time, and human resource constraints hinder
# the ability to conduct such experiments.
# To overcome the challenge of causal inference, we iden-
# tify an unanticipated and sudden leak of a highly proficient
# image-generative AI as a natural experiment , where mar-
# kets inadvertently encounter experimental and control con-
# ditions, resembling a scenario wherein nature or hackers or-arXiv:2311.07071v1  [econ.GN]  13 Nov 2023Figure 2: Model-free evidence. The three graphs show the trajectories of price, volume, and turnover for the ”wallpaper” and
# ”tachie” (anime character paintings) markets. The dashed lines represent the pivotal moment of an anime generative AI leak,
# designed to affect only the ”tachie” market. The post-leak landscape is intriguing. While the ”tachie” market experiences a dip
# in price, it experiences a surge in both volume and turnover, marking a departure from conventional intuition and illustrating
# the transformative potential of generative AI for market prosperity.
# chestrate an experiment.
# Among the pioneer platforms in the field, Novelai stands
# out as an early entrant, offering text-to-image generative AI
# services. These services come at a subscription fee of $10 to
# $25 per month per user. Powered by Stable Diffusion (Rom-
# bach et al. 2022), Novelai’s AI can swiftly generate anime-
# style images in response to specific keyword-based requests.
# However, in early October 2022, hackers attacked Novelai
# and leaked the AI model and training codes used by Novelai.
# Consequently, the leaked resources are accessible for down-
# load and local implementation, effectively reducing the cost
# of image generation to nearly zero.
# The inadvertent leak, which originated in the Western
# world, has inadvertently reverberated throughout the East-
# ern world. Prior to October 2022, China lacked domestic
# providers of generative AI, while access to foreign alter-
# natives was also impeded. After October 2022, however,
# the leaked AI, with accompanying tutorials, rapidly spread
# throughout China’s social media landscape. Consequently,
# this leak has expeditiously transitioned China from a state of
# being unaffected by generative AI to one of being affected.
# This leak served as an ideal natural experiment. First,
# China constitutes an environment where painting markets
# remained unaffected by generative AI before the leak as
# stated before. Secondly, the leaked AI exclusively special-
# izes in generating anime-style images, thereby exerting an
# impact solely on the anime painting markets while leaving
# other painting styles unaffected, allowing for a comparison
# between treated and control units. Thirdly, the unanticipated
# and sudden nature of the leak is exogenous. This attribute
# ensures that the product market is unlikely to have been af-
# fected by unobserved confounding factors since stakehold-
# ers had no time to react to the leak in advance. As a result,
# alternative explanations beyond the emergence of generative
# AI are effectively ruled out.
# We collected 197,110 records from a major Chinese paint-
# ing outsourcing platform from January 2022 to March 2023.
# This platform allows consumers to place orders with spec-ifications and budgets, and artists to fulfill them. The or-
# ders are segmented into distinct markets, such as anime, UI,
# live2d, and wallpaper. We transformed these order records
# into a market-week panel dataset, focusing on average price
# (price), the number of orders (volume), and total revenue
# (turnover). Using a difference-in-differences approach, we
# leveraged the unintended leak as a natural experiment. We
# compared the anime market (treated) with the wallpaper
# market (control). Our findings are summarized in Figure 2.
# Our analysis reveals a counterintuitive trend following the
# emergence of generative AI. Specifically, this emergence
# leads to a 64% reduction in the average price. However, it
# is intriguing that this reduction coincides with a remarkable
# 121% increase in the number of orders and a consequent
# 56% increase in total revenues. All estimates are statistically
# significant. This result suggests that rather than displacing
# artists, generative AI has a positive impact on their income,
# contributing to the industry’s overall prosperity.
# We provide a theoretical explanation for this finding us-
# ing the framework of the supply-and-demand model. On one
# hand, the emergence of generative AI has the potential to re-
# duce demand, as consumers gain the ability to satisfy their
# needs autonomously using this technology. Conversely, gen-
# erative AI simultaneously increases supply, given that pro-
# ducers become more efficient in their output. These two
# opposing dynamics—reduced demand and increased sup-
# ply—converge to explain our observed empirical results.
# The paper’s findings have significant societal implica-
# tions. Practitioners should integrate generative AI into their
# workflows rather than resist it. Embracing this technology
# can increase efficiency, ultimately translating to increased
# revenue. Policymakers, on the other hand, should view the
# increase in total revenue as a broader tax base. In this
# light, encouraging the utilization of generative AI becomes
# a more favorable approach than imposing restrictions. For
# AI communities, in addition to advocating for greater in-
# vestment, this study could assuage any unease and guilt that
# researchers may feel about the potential societal upheavalcaused by AI.
# In conclusion, this paper makes the following contribu-
# tions:
# • This paper pioneers the estimation of the impact of gen-
# erative AI, by exploiting an unexpected leak of a com-
# mercial generative AI as a novel natural experiment.
# • This paper presents a counterintuitive finding that gener-
# ative AI does not replace practitioners but instead con-
# tributes to industry prosperity, with significant societal
# implications for employment, legislation, and AI devel-
# opment.
# • The natural experiment identified in this paper estab-
# lishes a foundation for further research on the causal ef-
# fects of generative AI—its effects on quality in product
# markets, on wages in labor markets, and beyond.
# Related Literature
# This paper adopts empirical research methods to study gen-
# erative AI, which lies in the area of generative AI and the
# economics of IT.
# Generative AI
# Generative AI is defined as artificial intelligence (AI) algo-
# rithms that generate original outputs based on prompt inputs,
# which is distinguished from discriminative AI in that genera-
# tive AI synthesizes the data it has been trained on and creates
# similar content created by human experts (Wessel et al.).
# Generative AI has many applications, which can be cat-
# egorized by their output format. For text, the applications
# include machine translation (Bahdanau, Cho, and Bengio
# 2014), code generation (Svyatkovskiy et al. 2020), nat-
# ural language generation (Gatt and Krahmer 2018), etc.
# For images, the applications include text-to-image gener-
# ation (Ramesh et al. 2021), style transfer (Gatys, Ecker,
# and Bethge 2016), image translation (Isola et al. 2017),
# etc. For audio, the applications include text-to-speech (Ren
# et al. 2019), music composition (Fern ´andez and Vico 2013),
# singing voice conversion (Mohammadi and Kain 2017), etc.
# Generative AI’s underlying generative models include
# Autoregressive Model(AR) (MODEL 2013), Generative
# Adversarial Network (GAN) (Goodfellow et al. 2014), Nor-
# malizing Flow (Flow) (Rezende and Mohamed 2015), Vari-
# ational Auto-Encoder (V AE) (Kingma and Welling 2013),
# and Denoising Diffusion Probabilistic Model (Diffusion)
# (Ho, Jain, and Abbeel 2020). For example, OpenAI’s Chat-
# GPT adopts an autoregressive model (Brown et al. 2020)
# with Transformer architecture (Vaswani et al. 2017). The fo-
# cal generative AI in this paper, Novelai’s model (Rombach
# et al. 2022), adopts a diffusion model.
# Evaluation metrics of generative AI include human per-
# ception evaluation and statistical indicators, such as Incep-
# tion Scores (Salimans et al. 2016) and Frechet Inception Dis-
# tance (Heusel et al. 2017). Besides, downstream applications
# may have their specific evaluation metrics. For example, the
# survey (Zhao et al. 2023) systematically compares large lan-
# guage models on various NLP tasks.
# However, the correlation between quality and societal
# impact is not necessary. High quality doesn’t inherentlyguarantee a substantial, positive impact—it could range
# from high to low, even potentially negative. Take image-
# generative AI as an example: its social impact remained
# negligible during its early years, despite gradual quality im-
# provement. Initially, few users were engaged due to the infe-
# rior quality compared to human creations. However, a seis-
# mic shift occurred when its quality reached human stan-
# dards, triggering a sudden and significant social impact.
# Moreover, this impact could bear negative consequences
# such as artist unemployment. This paper’s significance lies
# in offering empirical evidence of generative AI’s societal im-
# pact. It navigates beyond the quality facade, capturing the
# intricate relationship between AI and societal outcomes.
# The Economics of IT
# The economics of information technology (IT) refers to the
# study of how IT affects markets, organizations, and individu-
# als, and how it changes the way businesses operate and make
# strategic decisions.
# The main research method for studying the economics
# of IT is empirical studies of observational data and exper-
# iments. Research questions usually take the form of what
# the impact of X on Y is. For example, the authors (Pamuru,
# Khern-am nuai, and Kannan 2021) examine the impact of an
# augmented reality game on local businesses, i.e., Pok ´emon
# Go on restaurants. In the context of AI, the research includes
# the impact of AI on education (Popenici and Kerr 2017), la-
# bor (Frank et al. 2019), healthcare (Wolff et al. 2020), etc.
# The vision paper (Brynjolfsson, Wang, and Zhang 2021)
# summarizes three criteria for evaluating new economics of
# IT research: questions should be novel and interesting; meth-
# ods should be correct and useful; outcomes should be impor-
# tant and impactful.
# This paper squarely meets the outlined criteria for sev-
# eral reasons. Firstly, it pioneers the exploration of genera-
# tive AI’s impact, a field that has rapidly gained significant
# societal attention since its inception. Secondly, it deftly navi-
# gates the challenge of causal inference through the ingenious
# identification of a novel natural experiment, which also es-
# tablishes a foundation for future research. Finally, the pa-
# per’s result is unexpected in that what was thought to be
# negative is actually positive, which has important implica-
# tions for various stakeholders.
# Empirical Strategy
# In this section, we compare different empirical methods for
# estimating the causal effects of generative AI. We apply
# our analysis under the potential outcome framework (Rubin
# 2005), the most widely used framework for causal inference.
# Pretest-Posttest Design and Experimental Design
# Suppose we are analyzing Nunits, labeled from 1toN.
# For each unit i, there are two potential outcomes {Y1i, Y0i}
# depending on whether he receives treatment or not ( Di=
# {0,1}). The individual treatment effect for unit iisY1i−Y0i.
# In this paper, the units are markets and the treatment is the
# emergence of generative AI.The main challenge for causal inference comes from the
# fact that only one potential outcome can be observed for
# each unit. For treated units ( Di= 1), we can only observe
# Y1i; for control units( Di= 0), we can only observe Y0i.
# As a result, individual treatment effects can never be esti-
# mated unless strong assumptions about the data generation
# process are made. As an alternative, researchers estimate the
# average treatment effect (ATE, E(Y1i−Y0i)) or the average
# treatment effect on the treated (ATT, E(Y1i−Y0i|Di= 1) ).
# We further extend our demonstration into two time pe-
# riods. In the pretest period ( t= 0 ), all units are not
# treated, where we can observe E(Y0(t= 0)|D= 0) and
# E(Y0(t= 0)|D= 1) . In the posttest period ( t= 1), the
# treated units ( D= 1) have received the treatment while
# the control units ( D= 0) remain untreated. We can ob-
# serve E(Y0(t= 1)|D= 0) andE(Y1(t= 1)|D= 1) .
# Our goal is to estimate ATE ( E(Y1(1))−E(Y0(1))) or ATT
# (E(Y1(1)|D= 1)−E(Y0(1)|D= 1) ).1
# A straightforward yet unsophisticated method is the
# pretest-posttest design, which compares the outcome vari-
# able before and after the treatment. Its estimator is
# E(Y1(1)|D= 1)−E(Y0(0)|D= 1) . However, ATT equals
# E(Y1(1)|D= 1)−E(Y0(1)|D= 1) = ( E(Y1(1)|D= 1)−
# E(Y0(0)|D= 1))−(E(Y0(1)|D= 1)−E(Y0(0)|D= 1)) ,
# which indicates that the estimator of the pretest-posttest de-
# sign is unbiased only if E(Y0(1)|D= 1)−E(Y0(0)|D=
# 1) = 0 , i.e., the outcome variable does not change for the
# treated units if they do not receive the treatment.
# However, the equation does not hold in the context of this
# study. A plausible explanation for this discrepancy could be
# the influence of seasonal effects. For example, the demand
# for anime images, which could naturally fluctuate after Oc-
# tober 2022 due to the start of a new academic semester for
# students. This intrinsic variability could potentially skew our
# estimates of the impact of generative AI, leading to underes-
# timates, overestimates, or even fundamentally incorrect es-
# timates. As a result, it’s clear that the pretest-posttest design
# is not an appropriate approach for this study.
# Another method is randomized experiments, also called
# a/b tests in some literature. This method randomly assigns
# units to a treated group ( D= 1 ) and a control group
# (D= 0), ensuring that the population of the treated group is
# the same as the population of the control group. So we have
# E(Y0(1)|D= 1) = E(Y0(1)|D= 0) . We can then derive
# ATT by subtracting E(Y1(1)|D= 1) from E(Y0(1)|D=
# 0), since we can observe both parts. Also, ATT is equal to
# ATE in randomized experiments. Thus, randomized experi-
# ments are considered the best method for causal inference.
# However, randomized experiments are not feasible in this
# study. While the individual level of analysis allows for the
# division of subjects into treatment and control groups, the
# challenge arises at the market level of analysis. Unlike in-
# dividuals, markets cannot be randomly assigned to different
# groups, which limits the ability to implement generative AI
# effects only on the treated group while leaving the control
# group unaffected. Macro-level analyses involving countries,
# 1Note that we still cannot observe another potential outcome
# (E(Y0(1) |D= 1) andE(Y1(1) |D= 0) ).
# Figure 3: NovelAI’s AI-generated images.
# cities, and industries face similar limitations. In these con-
# texts, researchers have to gain valuable insights from obser-
# vational data rather than from controlled interventions.
# Difference-In-Differences Design
# Difference-in-differences (DID) is arguably the most popu-
# lar research design in the quantitative social sciences. It can
# be traced back to 1855 (Snow 1856) and has also made great
# strides in recent years (Goodman-Bacon 2021).
# The DID estimator is E(Y1(1)|D= 1)−E(Y0(0)|D=
# 1)−(E(Y0(1)|D= 0)−E(Y0(0)|D= 0)) . DID first calcu-
# lates the differences between the pretest and posttest periods
# for each group. DID then takes the difference between these
# two differences as the estimator.
# The DID design is based on the parallel trend assumption
# that the trends in the outcome variable for the treatment and
# control groups would have been parallel in the absence of
# the treatment. Formally, the DID estimator equals ATT if
# E(Y0(1)|D= 1)−E(Y0(0)|D= 1) = E(Y0(1)|D= 0)−
# E(Y0(0)|D= 0) . In practice, the parallel trend assumption
# is considered satisfied if the treatment and control groups
# have similar pre-treatment trends in the outcome variable.
# Essentially, the use of the difference-in-differences (DID)
# method to study the impact of generative AI on product
# markets depends on three crucial conditions: an appropri-
# ate treatment that affects treated markets after the treatment
# and not before, minimal impact on control markets, and the
# fulfillment of the parallel trend assumption between treated
# and control markets.
# In this study, the DID design is skillfully exploited via
# the unanticipated leakage. The parallel trajectories of treated
# and control units, shown in Figure 2, attest to the DID de-
# sign. This alignment of outcome variables prior to the leak,
# characterized by stability, supports the validity of the paral-
# lel trend assumption.
# Research Context and Data
# The NovelAI ”experiment”
# NovelAI is one of the commercial websites offering gener-
# ative AI services. NovelAI was initially launched on June
# 15, 2021, when it only provided AI story-writing services.
# After Stable Diffusion, a state-of-the-art text-to-image algo-
# rithm, was released on March 2, 2023, NovelAI began of-
# fering its text-to-image services. NovelAI put a lot of effortinto collecting anime-style images and used them to train an
# anime-style generative AI model based on Stable Diffusion.
# NovelAI’s text-to-image service was implemented on Octo-
# ber 3, 2022 (NovelAI 2022).
# NovelAI’s generative AI takes a series of prompts, or key-
# words, such as ”masterpiece, magical girl, fantasy, caustic”
# as input. The generative AI will generate images according
# to the prompts. Figure 3 shows some examples of NovelAI.
# Note that NovelAI’s AI only generates anime-style images
# because it is trained on anime-style images.
# NovelAI’s generative AI can generate an image in a few
# seconds and can generate multiple images simultaneously.
# The cost of generating an image depends on its quality
# and resolution size. NovelAI uses a monthly subscription
# scheme ranging from $10 to $25. $10 users can generate
# approximately 200 images of normal quality per month. $25
# users can generate an unlimited number of such images.
# However, on October 3, 2022, a few days after NovelAI’s
# text-to-image service was released, hackers attacked Nove-
# lAI’s server and released its AI model and associated train-
# ing code. Anyone can download the leaked material via a
# shared seed and implement the same AI locally, allowing
# people to generate an image in a few seconds for free.
# This leak creates an ideal natural experiment in China.
# First, China provides an environment where painting mar-
# kets had not been affected by generative AI before the leak.
# China did not yet have a local generative AI provider, and
# people cannot access foreign generative AI providers due
# to policy restrictions, language restrictions, and payment re-
# strictions. However, since October 2022, the leaked AI and
# related tutorials have been widely disseminated on Chinese
# social media, as if the leak had created an experimental treat-
# ment in China. Second, the leaked AI only generates anime-
# style images. Thus, it only affects the anime painting mar-
# kets, but not the painting markets of other styles, which al-
# lows a comparison between the treated units and the control
# units. Third, the leak was sudden and unexpected, creating
# an exogenous natural experiment. The product market was
# unlikely to be affected by unobserved confounders, as stake-
# holders cannot react prior to the leak, ruling out alternative
# explanations other than generative AI.
# Data Description
# We collect data from one of the largest painting outsourcing
# platforms in China. Consumers, as demanders, can post an
# order on the focal platform, and artists, as producers, can
# express their interest in accepting the order. The consumer
# can then select one of the interested artists and enter into a
# contract with the selected artist. After the artist completes
# the task, the consumer pays the bill. The platform acts as a
# guarantee at 5% of the price.
# An order on the focal platform consists of an art
# category, range of price, and description. The art cate-
# gory includes ”original character”, ”artwork”, ”avatar”, ”Q
# style”, ”tachie”, ”wallpaper”, ”live2d”, ”scenario”, ”cover”,
# ”poster”, ”UI”, ”character design”, and ”CG”. The price
# range contains a lower and an upper bound, such as 50 to
# 200 yuan. The order description specifies the requirement,
# such as ”a wallpaper for vtuber live streaming background”.
# Panel A: Focal Categories
# Price 843.5 460.8 334.6 628.0 2473.2
# Volume 124.0 55.0 12.0 130.0 324.0
# Turnover 92496.3 45201.3 6000.0 78950.0 264504.0
# Price upper 2236.2 869.2 1212.2 1942.7 4689.1
# Turnover upper 252298.1 103799.1 21550.0 230810.0 655574.0
# Panel B: All Categories
# Price 831.2 808.7 0.0 567.6 7338.7
# Volume 240.7 376.9 0.0 86.0 2666.0
# Turnover 108009.3 120991.1 0.0 64176.0 532007.0
# Price upper 2124.5 1645.6 0.0 1721.7 12462.5
# Turnover upper 384122.1 541810.5 0.0 173980.0 3117916.0
# Table 1: Summary Statistics
# We collected data on the focal platform from January
# 2022 to February 2023, which contains 197,506 orders in
# total. We removed 396 outlier orders whose price is more
# than 70,000 yuan (about $10,000) because they are too ex-
# pensive to become real orders. We then aggregate the data to
# the category-week level. For each category and each week,
# we calculate the average price (price), the number of orders
# (volume), and the total revenue (turnover). The average price
# and total revenue are based on the lower bound because the
# lower bound may better reflect the true willingness of con-
# sumers to accept their orders than the upper bound.
# We choose the category ”tachie” as the treated unit. The
# ”tachie” is a Japanese term in the context of anime, manga,
# and video games that refers to the full-body standing draw-
# ing of a character.2The ”tachie” is exactly the style that Nov-
# elAI’s generative AI produces. Therefore, we consider the
# ”tachie” category as the market affected by generative AI.
# On the other hand, we choose the ”wallpaper” as the con-
# trol unit. A control unit should be comparable to the treated
# unit, so we do not select ”live2d”, ”UI”, and ”CG” because
# they are beyond the scope of paintings. As for the rest of the
# categories, they are likely to be partially affected by Nove-
# lAI’s generative AI, because the generative AI may only be
# useful with careful prompt engineering and post-processing.
# Using them as a control unit may underestimate the impact
# of generative AI. The ”wallpaper” may be the best control
# unit because NovelAI’s generative AI is unlikely to generate
# elaborate wallpapers.
# Table 1 presents the summary statistics for the category-
# week panel dataset in this paper. Panel A shows the statistics
# for the ”tachie” and ”wallpaper” categories; Panel B shows
# the statistics for all categories. Price refers to the average
# price. Volume refers to the number of orders. Turnover refers
# to the total revenue. The currency of Price andTurnover is
# Chinese yuan (7 yuan = $1). Also, we show the price and
# turnover based on the upper bound, which is Price upper
# andTurnover upper .
# 2https://en.wiktionary.org/wiki/%E7%AB%8B%E3%81%
# A1%E7%B5%B5#JapaneseDependent Variables: price volume turnover log(price) log(volume) log(turnover)
# Model: (1) (2) (3) (4) (5) (6)
# Variables
# treated ×after -646.6∗∗∗140.9∗∗∗57,070.5∗∗∗-0.643∗∗∗1.21∗∗∗0.568∗∗∗
# (2.8×10−12) ( 4.7×10−13) ( 1.9×10−10) ( 2.4×10−15) ( 5.1×10−15) ( 2.4×10−15)
# Fixed-effects
# category Yes Yes Yes Yes Yes Yes
# week Yes Yes Yes Yes Yes Yes
# Fit statistics
# Observations 126 126 126 126 126 126
# R20.88161 0.89675 0.84415 0.91458 0.93939 0.88511
# Within R20.49279 0.78784 0.37401 0.53132 0.83287 0.35682
# Clustered (category) standard-errors in parentheses
# Signif. Codes: ***: 0.01, **: 0.05, *: 0.1
# Table 2: The Impact of Generative AI on Product Markets
# Findings
# This chapter presents the findings of this study that examines
# the impact of generative AI on product markets.
# We use the standard multi-periods model specification of
# difference-in-differences with two-way fixed effects (Call-
# away and Sant’Anna 2021):
# yit=αi+δt+β·treated iafter t+εit (1)
# In this model, the variable yitrepresents one of our out-
# come variables by category iin week t.treated iis a dummy
# variable indicating whether category ibelongs to the treated
# group ( treated i= 1) or the control group ( treated i= 0).
# after tis also a dummy variable indicating whether week
# tis after the natural experiment ( after t= 1) or before the
# natural experiment ( after t= 0). The model includes a fixed
# effect δtfor each week to control for observed and unob-
# served nonparametric time trends. Additionally, the model
# includes a fixed effect αifor each category to account for
# time-invariant differences between categories. The parame-
# ter of interest is β, which captures the impact of generative
# AI on the focal outcome variable.
# Table 2 shows the estimates for the change in price, vol-
# ume, and turnover in models (1) to (3), respectively. The co-
# efficient estimate of price is -646, indicating generative AI
# lowered the average price by 646 yuan. Notably, the coeffi-
# cient estimates of volume and turnover are 140 and 57,070,
# showing that generative AI increased the number of orders
# by 140 per week and increased the total revenue by 57,070
# yuan per week. In addition, models (4) to (6) take the loga-
# rithm of price, volume, and turnover and show their percent-
# age change. The results show that price decreased by 64%,
# volume increased by 121%, and turnover increased by 56%.
# Generative AI allows users to create their own images
# without the help of artists. Therefore, it is believed that the
# number of artwork orders will decrease due to generative AI.
# What’s more, artists will compete for the shrinking number
# of orders by lowering their prices. The reduced volume timesthe reduced price leads to a double reduction in sales, i.e. a
# market depression.
# However, our results show that this is not the case. Al-
# though the average price drops significantly to a third of its
# original price after the emergence of generative AI, the num-
# ber of orders is more than doubled. The corresponding result
# for revenue is also a pronounced increase of up to 56%.
# Individuals’ attitudes toward generative AI are often
# rooted in their anticipation of the economic ramifications
# associated with its adoption. In particular, there is an un-
# derstandable concern among various segments, including
# artists, that generative AI could lead to feelings of displace-
# ment, given the fear of rapid and unceremonious replace-
# ment after years of dedicated study and creative toil. How-
# ever, our empirical findings provide a counterintuitive in-
# sight, revealing that, contrary to initial impressions, genera-
# tive AI can yield beneficial outcomes for practitioners. This
# is evidenced by a discernible increase in order volume, un-
# derscoring increased opportunities that accelerate the evo-
# lution of their artistic endeavors by providing an invaluable
# platform for rapid prototyping and iterative refinement. Be-
# sides, the resulting escalation in revenue contributes directly
# to their prosperity, as every monetary transaction paid by
# consumers invariably contributes to the artists’ earnings.
# Theoretical Explanation
# In this section, we provide theoretical explanations for the
# counterintuitive impact of generative AI by using the classic
# supply and demand model in microeconomics.
# The supply and demand model explains how prices and
# quantities of goods and services are determined in a market,
# as shown in Figure 4(a). It revolves around the interaction
# between two key forces: supply and demand.
# Supply refers to the quantity of a good that producers are
# willing to offer for sale at different price levels. Demand rep-
# resents the willingness of consumers to purchase a certain
# quantity of a good at various price levels. The relationshipFigure 4: Theoretical Economic Explanations for the Impact of Generative AI
# between price and quantity supplied is depicted on a supply
# curve, which slopes upward from left to right; the relation-
# ship between price and quantity demanded is illustrated on
# a demand curve, which slopes downward from left to right.
# The equilibrium price and quantity in a market are deter-
# mined by the intersection of the demand and supply curves.
# This point is known as the market equilibrium. The equilib-
# rium in Figure 4(a) is (Q0, P0), which represents the market
# equilibrium before generative AI.
# We argue that Generative AI can shift the demand curve
# inward and the supply curve outward.
# Consumers might prefer AI-generated content over real-
# world alternatives because they are cheaper, more conve-
# nient, or customizable. As a result, these AI-generated alter-
# natives are close substitutes for real-world products, which
# might reduce consumer demand for the actual products and
# lead to a shift in the demand curve inward (Figure 4(b)).
# However, generative AI can also increase production ef-
# ficiency for producers. To illustrate, consider the scenario
# where artists employ generative AI to initially generate an
# image at 80% quality. Subsequently, human can refine the
# generated output to achieve 100% quality. The increased ef-
# ficiency can lead to increased supply as producers are able
# to produce more output within the same amount of time and
# effort, shifting the demand curve outward (Figure 4(c)).
# Shifting the demand curve inward reduces the equilibrium
# price and quantity. Shifting the supply curve outward re-
# duces the price but increases the quantity. Generative AI can
# shift both the demand curve inward and the supply curve
# outward, which has two possible equilibria: in Figure 4(d),
# both price and quantity decrease ( P1< P 0, Q1< Q 0) rela-
# tive to the initial equilibrium; in Figure 4(e), price decreases
# but quantity increases ( P2< P 0, Q2> Q 0).
# The supply and demand model provides two possible out-
# comes for the impact of generative AI. In turn, our empirical
# results show that its impact belongs to the more promising
# category, Figure 4(e), of the two. Moreover, our empirical
# results show that turnover ( PQ) also increases, which is am-
# biguous according to the supply and demand model.
# Implications
# The counterintuitive findings in this paper have significant
# implications for various stakeholders.
# Practitioners . The most direct implication for practition-
# ers is that they should welcome generative AI instead of re-sisting it, because generative AI can increase their income
# and make their industry more prosperous. As economic the-
# ory suggests, generative AI helps them by increasing their
# efficiency. As a result, practitioners should think about how
# to incorporate generative AI into their workflow to improve
# it. For example, in the past, artists completed a painting by
# sketching, line drawing, and coloring. They can use genera-
# tive AI to get a base and ”fine tune” it in the future.
# Policymakers . Although generative AI has other issues,
# such as intellectual property concerns, policy making is a
# comprehensive consideration. This paper provides empiri-
# cal evidence in favor of generative AI in that it can increase
# taxes and contribute to upstream and downstream markets
# by increasing the number of orders and total revenue. On
# the other hand, a misunderstanding of the economic conse-
# quences of generative AI may lead to a wrong policy, caus-
# ing the country to miss out on the new wave of development
# brought by AI.
# AI community . When the concept of artificial intelli-
# gence was born, so were the fears that AI could destroy hu-
# man society. In the movie The Terminator, the AI system
# invented by computer scientists ultimately caused the end of
# the world. In addition to lobbying for more investment in the
# AI community, this article can, more importantly, assuage
# any unease and guilt that researchers may feel because the
# empirical evidence in the article shows that generative AI is
# augmenting humans rather than replacing them.
# Conclusions and Future Directions
# This paper provides empirical evidence that generative AI,
# while decreasing price, surprisingly increases volume and
# turnover in product markets, as a result of decreasing de-
# mand and increasing supply.
# We identified an unexpected and sudden leakage of a
# highly proficient image-generating AI as a natural experi-
# ment for causality. This natural experiment allows for an-
# swering many critical research questions. A new research
# question could delve deeper into the outcome variables in
# this paper, such as how demand/orders change after genera-
# tive AI. Also, a new research question could be another im-
# portant outcome variable, such as what’s the impact of gen-
# erative AI on product quality. In addition, a new research
# question could relate to another area, such as what’s the im-
# pact of generative AI on labor markets.
# Bahdanau, D.; Cho, K.; and Bengio, Y . 2014. Neural ma-
# chine translation by jointly learning to align and translate.
# arXiv preprint arXiv:1409.0473 .
# Brown, T.; Mann, B.; Ryder, N.; Subbiah, M.; Kaplan, J. D.;
# Dhariwal, P.; Neelakantan, A.; Shyam, P.; Sastry, G.; Askell,
# A.; et al. 2020. Language models are few-shot learners. Ad-
# vances in neural information processing systems , 33: 1877–
# 1901.
# Brynjolfsson, E.; Wang, C.; and Zhang, X. 2021. The eco-
# nomics of IT and digitization: Eight questions for research.
# MIS quarterly , 45(1): 473–477.
# Callaway, B.; and Sant’Anna, P. H. 2021. Difference-in-
# differences with multiple time periods. Journal of econo-
# metrics , 225(2): 200–230.
# Fern ´andez, J. D.; and Vico, F. 2013. AI methods in algo-
# rithmic composition: A comprehensive survey. Journal of
# Artificial Intelligence Research , 48: 513–582.
# Frank, M. R.; Autor, D.; Bessen, J. E.; Brynjolfsson, E.; Ce-
# brian, M.; Deming, D. J.; Feldman, M.; Groh, M.; Lobo, J.;
# Moro, E.; et al. 2019. Toward understanding the impact of
# artificial intelligence on labor. Proceedings of the National
# Academy of Sciences , 116(14): 6531–6539.
# Friedman, M. 1953. The methodology of positive eco-
# nomics.
# Gatt, A.; and Krahmer, E. 2018. Survey of the state of the
# art in natural language generation: Core tasks, applications
# and evaluation. Journal of Artificial Intelligence Research ,
# 61: 65–170.
# Gatys, L. A.; Ecker, A. S.; and Bethge, M. 2016. Image style
# transfer using convolutional neural networks. In Proceed-
# ings of the IEEE conference on computer vision and pattern
# recognition , 2414–2423.
# Goodfellow, I.; Pouget-Abadie, J.; Mirza, M.; Xu, B.;
# Warde-Farley, D.; Ozair, S.; Courville, A.; and Bengio, Y .
# 2014. Generative adversarial nets. Advances in neural in-
# formation processing systems , 27.
# Goodman-Bacon, A. 2021. Difference-in-differences with
# variation in treatment timing. Journal of Econometrics ,
# 225(2): 254–277.
# Heusel, M.; Ramsauer, H.; Unterthiner, T.; Nessler, B.; and
# Hochreiter, S. 2017. Gans trained by a two time-scale up-
# date rule converge to a local nash equilibrium. Advances in
# neural information processing systems , 30.
# Ho, J.; Jain, A.; and Abbeel, P. 2020. Denoising diffusion
# probabilistic models. Advances in neural information pro-
# cessing systems , 33: 6840–6851.
# Isola, P.; Zhu, J.-Y .; Zhou, T.; and Efros, A. A. 2017. Image-
# to-image translation with conditional adversarial networks.
# InProceedings of the IEEE conference on computer vision
# and pattern recognition , 1125–1134.
# Kingma, D. P.; and Welling, M. 2013. Auto-encoding varia-
# tional bayes. arXiv preprint arXiv:1312.6114 .
# MODEL, A. 2013. SYSTEM IDENTIFICATION AND.
# InInstrumentation, Control and Automation of Water andWastewater Treatment and Transport Systems: Proceedings
# of the 5th IAWPRC Workshop Held in Yokohama and Kyoto,
# Japan, 26 July–3 August 1990 , 121. Elsevier.
# Mohammadi, S. H.; and Kain, A. 2017. An overview of
# voice conversion systems. Speech Communication , 88: 65–
# 82.
# NovelAI. 2022. Image Generation Announcement.
# https://blog.novelai.net/image-generation-announcement-
# 807b3cf0afec.
# Pamuru, V .; Khern-am nuai, W.; and Kannan, K. 2021. The
# impact of an augmented-reality game on local businesses: A
# study of Pok ´emon go on restaurants. Information Systems
# Research , 32(3): 950–966.
# Popenici, S. A.; and Kerr, S. 2017. Exploring the impact
# of artificial intelligence on teaching and learning in higher
# education. Research and Practice in Technology Enhanced
# Learning , 12(1): 1–13.
# Ramesh, A.; Pavlov, M.; Goh, G.; Gray, S.; V oss, C.; Rad-
# ford, A.; Chen, M.; and Sutskever, I. 2021. Zero-shot text-to-
# image generation. In International Conference on Machine
# Learning , 8821–8831. PMLR.
# Ren, Y .; Ruan, Y .; Tan, X.; Qin, T.; Zhao, S.; Zhao, Z.; and
# Liu, T.-Y . 2019. Fastspeech: Fast, robust and controllable
# text to speech. Advances in neural information processing
# systems , 32.
# Rezende, D.; and Mohamed, S. 2015. Variational inference
# with normalizing flows. In International conference on ma-
# chine learning , 1530–1538. PMLR.
# Rombach, R.; Blattmann, A.; Lorenz, D.; Esser, P.; and Om-
# mer, B. 2022. High-resolution image synthesis with latent
# diffusion models. In Proceedings of the IEEE/CVF confer-
# ence on computer vision and pattern recognition , 10684–
# 10695.
# Rubin, D. B. 2005. Causal inference using potential out-
# comes: Design, modeling, decisions. Journal of the Ameri-
# can Statistical Association , 100(469): 322–331.
# Salimans, T.; Goodfellow, I.; Zaremba, W.; Cheung, V .; Rad-
# ford, A.; and Chen, X. 2016. Improved techniques for train-
# ing gans. Advances in neural information processing sys-
# tems, 29.
# Snow, J. 1856. On the mode of communication of cholera.
# Edinburgh medical journal , 1(7): 668.
# Svyatkovskiy, A.; Deng, S. K.; Fu, S.; and Sundaresan, N.
# 2020. Intellicode compose: Code generation using trans-
# former. In Proceedings of the 28th ACM Joint Meeting
# on European Software Engineering Conference and Sym-
# posium on the Foundations of Software Engineering , 1433–
# 1443.
# Vaswani, A.; Shazeer, N.; Parmar, N.; Uszkoreit, J.; Jones,
# L.; Gomez, A. N.; Kaiser, Ł.; and Polosukhin, I. 2017. At-
# tention is all you need. Advances in neural information pro-
# cessing systems , 30.
# Wessel, M.; Adam, M.; Benlian, A.; and Thies, F. ???? Gen-
# erative AI and its Transformative Value for Digital Plat-
# forms.Wolff, J.; Pauling, J.; Keck, A.; and Baumbach, J. 2020. The
# economic impact of artificial intelligence in health care: sys-
# tematic review. Journal of medical Internet research , 22(2):
# e16866.
# Zhao, W. X.; Zhou, K.; Li, J.; Tang, T.; Wang, X.;
# Hou, Y .; Min, Y .; Zhang, B.; Zhang, J.; Dong, Z.; et al.
# 2023. A survey of large language models. arXiv preprint
# arXiv:2303.18223 .

# %% [markdown]
# ### **Step 4: Count the Tokens in the Extracted Text**
#
# *   Define a function to count the tokens in a text string.
# *   Count the tokens in the extracted text.
# *   Print the number of tokens.

# %%
# Define a function to count the tokens in a text string
def num_tokens_from_string(string: str, encoding_name: str) -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")
    num_tokens = len(encoding.encode(string))
    return num_tokens

# Count the tokens in the extracted text
num_tokens = num_tokens_from_string(text_body, "gpt-3.5-turbo")

# Print the number of tokens
print(num_tokens)
# Out:
# 10556

# %% [markdown]
# ### **Step 5: Use LangChain to Generate a Summary of the Paper**
#
# *   Define the system and human prompts.
# *   Create the **ChatPromptTemplate** object.
# *   Create the **ChatOpenAI** object.
# *   Create the **LLMChain** object.
# *   Run the **LLMChain**.
# *   Print the output.

# %%
# Define the system prompt
context_template = "You are a helpful AI Researcher that specializes in analyzing ML, AI, and LLM papers. Please use all your expertise to approach this task. Output your content in markdown format and include titles where relevant."
system_message_prompt = SystemMessagePromptTemplate.from_template(context_template)

# Define the human prompt
human_template = "Please summarize this paper focusing on the key important takeaways for each section. Expand the summary on methods so they can be clearly understood. \n\n PAPER: \n\n{paper_content}"
human_message_prompt = HumanMessagePromptTemplate(
        prompt=PromptTemplate(
            template=human_template,
            input_variables=["paper_content"],
        )
    )

# Create the ChatPromptTemplate object
chat_prompt_template = ChatPromptTemplate.from_messages([system_message_prompt, human_message_prompt])

# Create the ChatOpenAI object
chat = ChatOpenAI(model_name="gpt-3.5-turbo-16k", temperature=0.2)

# Create the LLMChain object
summary_chain = LLMChain(llm=chat, prompt=chat_prompt_template)

# Run the LLMChain and print the output
with get_openai_callback() as cb:
    output = summary_chain.run(text_body)
print(output)
# Out:
# # Summary of "The Impact of Generative Artificial Intelligence"
#
# ## Abstract
# This paper examines the impact of generative artificial intelligence (AI) on product markets. The authors use a natural experiment, an unexpected leak of a highly proficient image-generative AI, to study the effects of generative AI on prices, order volume, and overall revenue. Surprisingly, the results show that while generative AI lowers average prices, it substantially boosts order volume and overall revenue. This counterintuitive finding suggests that generative AI confers benefits upon artists rather than detriments.
#
# ## Introduction
# Generative AI has raised concerns about unemployment and market depression. Artists have protested against AI-generated images, and policymakers are considering regulations to limit generative AI use. This paper empirically examines the impact of generative AI on product markets to bridge the gaps in understanding.
#
# ## Methods
# To overcome the challenge of causal inference, the authors identify an unanticipated leak of a highly proficient image-generative AI as a natural experiment. They collect real-world data from an artwork outsourcing platform and compare the anime market (treated) with the wallpaper market (control) using a difference-in-differences approach.
#
# ## Findings
# The results show that generative AI lowers average prices by 64%, but it also leads to a remarkable 121% increase in the number of orders and a 56% increase in total revenue. This counterintuitive finding suggests that generative AI benefits artists and contributes to market prosperity.
#
# ## Theoretical Explanation
# The authors provide a theoretical explanation using the supply and demand model. Generative AI reduces demand as consumers gain the ability to satisfy their needs autonomously, but it also increases supply as producers become more efficient. These opposing dynamics converge to explain the observed empirical results.
#
# ## Implications
# The findings have significant implications for practitioners, policymakers, and the AI community. Practitioners should integrate generative AI into their workflows to increase efficiency and revenue. Policymakers should view the increase in total revenue as a broader tax base and encourage the utilization of generative AI. The AI community can be reassured that generative AI augments humans rather than replacing them.
#
# ## Conclusion
# This paper pioneers the estimation of the impact of generative AI and provides empirical evidence that generative AI benefits artists and contributes to market prosperity. The natural experiment identified in this paper establishes a foundation for further research on the causal effects of generative AI.

# %% [markdown]
# ### **Conclusion**
#
# This demo provides a step-by-step guide on how to build an Arxiv paper summarizer using Python. By following these steps, you have created your own paper summarizer that can read a paper in one shot and generate a summary.
#
# **Note:**
# *   Save the output as a text file.
# *   Name the text file **Summary.txt**.
# *   This file will be used in the next session for benchmarking purposes.
